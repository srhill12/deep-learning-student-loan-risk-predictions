# %% [markdown]
# <a href="https://colab.research.google.com/github/srhill12/neural-network-challenge-1/blob/main/Copy_of_student_loans_with_deep_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Student Loan Risk with Deep Learning

# %%
# Imports
import pandas as pd
import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report
from pathlib import Path

# %% [markdown]
# ---
#
# ## Prepare the data to be used on a neural network model

# %% [markdown]
# ### Step 1: Read the `student-loans.csv` file into a Pandas DataFrame. Review the DataFrame, looking for columns that could eventually define your features and target variables.

# %%
# Read the csv into a Pandas DataFrame
file_path = "https://static.bc-edx.com/ai/ail-v-1-0/m18/lms/datasets/student-loans.csv"
loans_df = pd.read_csv(file_path)

# Review the DataFrame
loans_df.head()
# Out:
#    payment_history  location_parameter  stem_degree_score  gpa_ranking  \
# 0              7.4                0.70               0.00          1.9
# 1              7.8                0.88               0.00          2.6
# 2              7.8                0.76               0.04          2.3
# 3             11.2                0.28               0.56          1.9
# 4              7.4                0.70               0.00          1.9
#
#    alumni_success  study_major_code  time_to_completion  \
# 0           0.076              11.0                34.0
# 1           0.098              25.0                67.0
# 2           0.092              15.0                54.0
# 3           0.075              17.0                60.0
# 4           0.076              11.0                34.0
#
#    finance_workshop_score  cohort_ranking  total_loan_score  \
# 0                  0.9978            3.51              0.56
# 1                  0.9968            3.20              0.68
# 2                  0.9970            3.26              0.65
# 3                  0.9980            3.16              0.58
# 4                  0.9978            3.51              0.56
#
#    financial_aid_score  credit_ranking
# 0                  9.4               0
# 1                  9.8               0
# 2                  9.8               0
# 3                  9.8               1
# 4                  9.4               0

# %%
# Review the data types associated with the columns
loans_df.dtypes
# Out:
# payment_history           float64
# location_parameter        float64
# stem_degree_score         float64
# gpa_ranking               float64
# alumni_success            float64
# study_major_code          float64
# time_to_completion        float64
# finance_workshop_score    float64
# cohort_ranking            float64
# total_loan_score          float64
# financial_aid_score       float64
# credit_ranking              int64
# dtype: object

# %%
# Check the credit_ranking value counts
loans_df["credit_ranking"].value_counts()
# Out:
# credit_ranking
# 1    855
# 0    744
# Name: count, dtype: int64

# %% [markdown]
# ### Step 2: Using the preprocessed data, create the features (`X`) and target (`y`) datasets. The target dataset should be defined by the preprocessed DataFrame column “credit_ranking”. The remaining columns should define the features dataset.

# %%
# Define the target set y using the credit_ranking column
y = loans_df["credit_ranking"]

# Display a sample of y
loans_df["credit_ranking"].head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    1
# 4    0
# Name: credit_ranking, dtype: int64

# %%
# Define features set X by selecting all columns but credit_ranking
X = loans_df.drop(columns="credit_ranking")

# Review the features DataFrame
loans_df.head()
# Out:
#    payment_history  location_parameter  stem_degree_score  gpa_ranking  \
# 0              7.4                0.70               0.00          1.9
# 1              7.8                0.88               0.00          2.6
# 2              7.8                0.76               0.04          2.3
# 3             11.2                0.28               0.56          1.9
# 4              7.4                0.70               0.00          1.9
#
#    alumni_success  study_major_code  time_to_completion  \
# 0           0.076              11.0                34.0
# 1           0.098              25.0                67.0
# 2           0.092              15.0                54.0
# 3           0.075              17.0                60.0
# 4           0.076              11.0                34.0
#
#    finance_workshop_score  cohort_ranking  total_loan_score  \
# 0                  0.9978            3.51              0.56
# 1                  0.9968            3.20              0.68
# 2                  0.9970            3.26              0.65
# 3                  0.9980            3.16              0.58
# 4                  0.9978            3.51              0.56
#
#    financial_aid_score  credit_ranking
# 0                  9.4               0
# 1                  9.8               0
# 2                  9.8               0
# 3                  9.8               1
# 4                  9.4               0

# %% [markdown]
# ### Step 3: Split the features and target sets into training and testing datasets.

# %%
# Split the preprocessed data into a training and testing dataset
# Assign the function a random_state equal to 1
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %% [markdown]
# ### Step 4: Use scikit-learn's `StandardScaler` to scale the features data.

# %%
# Create a StandardScaler instance
X_scaler = StandardScaler()

# Fit the scaler to the features training dataset
X_scaler.fit(X_train)

# Fit the scaler to the features training dataset
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ---
#
# ## Compile and Evaluate a Model Using a Neural Network

# %% [markdown]
# ### Step 1: Create a deep neural network by assigning the number of input features, the number of layers, and the number of neurons on each layer using Tensorflow’s Keras.
#
# > **Hint** You can start with a two-layer deep neural network model that uses the `relu` activation function for both layers.

# %%
# Define the the number of inputs (features) to the model
input_nodes = len(X.columns)

# Review the number of features
input_nodes
# Out:
# 11

# %%
# Define the number of hidden nodes for the first hidden layer
hidden_nodes_layer1 = 6

# Define the number of hidden nodes for the second hidden layer
hidden_nodes_layer2 = 3

# Define the number of neurons in the output layer
output_layer = 1

# %%
# Create the Sequential model instance
nn_model = tf.keras.models.Sequential()

# Add the first hidden layer
nn_model.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, activation="relu", input_dim=input_nodes))

# Add the second hidden layer
nn_model.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# Add the output layer to the model specifying the number of output neurons and activation function
nn_model.add(tf.keras.layers.Dense(units=output_layer, activation="sigmoid"))

# %%
# Display the Sequential model summary
nn_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 6)                 72
#
#  dense_7 (Dense)             (None, 3)                 21
#
#  dense_8 (Dense)             (None, 1)                 4
#
# =================================================================
# Total params: 97 (388.00 Byte)
# Trainable params: 97 (388.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Step 2: Compile and fit the model using the `binary_crossentropy` loss function, the `adam` optimizer, and the `accuracy` evaluation metric.

# %%
# Compile the Sequential model
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Fit the model using 50 epochs and the training data
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=50)
# Out:
# Epoch 1/50
# 38/38 [==============================] - 1s 2ms/step - loss: 0.7065 - accuracy: 0.4796
# Epoch 2/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6831 - accuracy: 0.5396
# Epoch 3/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6655 - accuracy: 0.5705
# Epoch 4/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6519 - accuracy: 0.5922
# Epoch 5/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6392 - accuracy: 0.6239
# Epoch 6/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6272 - accuracy: 0.6397
# Epoch 7/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6155 - accuracy: 0.6647
# Epoch 8/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.6045 - accuracy: 0.6706
# Epoch 9/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5941 - accuracy: 0.6756
# Epoch 10/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5848 - accuracy: 0.6689
# Epoch 11/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5765 - accuracy: 0.6781
# Epoch 12/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5695 - accuracy: 0.6831
# Epoch 13/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5638 - accuracy: 0.6872
# Epoch 14/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5587 - accuracy: 0.6906
# Epoch 15/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5544 - accuracy: 0.6931
# Epoch 16/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5509 - accuracy: 0.6981
# Epoch 17/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5484 - accuracy: 0.7023
# Epoch 18/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5447 - accuracy: 0.7081
# Epoch 19/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5425 - accuracy: 0.7139
# Epoch 20/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5404 - accuracy: 0.7189
# Epoch 21/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5389 - accuracy: 0.7206
# Epoch 22/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5370 - accuracy: 0.7248
# Epoch 23/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5355 - accuracy: 0.7281
# Epoch 24/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5342 - accuracy: 0.7281
# Epoch 25/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5329 - accuracy: 0.7289
# Epoch 26/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5319 - accuracy: 0.7264
# Epoch 27/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5309 - accuracy: 0.7256
# Epoch 28/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5299 - accuracy: 0.7239
# Epoch 29/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5293 - accuracy: 0.7239
# Epoch 30/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5285 - accuracy: 0.7256
# Epoch 31/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.5275 - accuracy: 0.7273
# Epoch 32/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5265 - accuracy: 0.7273
# Epoch 33/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5259 - accuracy: 0.7306
# Epoch 34/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5251 - accuracy: 0.7314
# Epoch 35/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5241 - accuracy: 0.7339
# Epoch 36/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5231 - accuracy: 0.7331
# Epoch 37/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5227 - accuracy: 0.7348
# Epoch 38/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5217 - accuracy: 0.7331
# Epoch 39/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5210 - accuracy: 0.7339
# Epoch 40/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.5199 - accuracy: 0.7314
# Epoch 41/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5192 - accuracy: 0.7323
# Epoch 42/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5184 - accuracy: 0.7331
# Epoch 43/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5175 - accuracy: 0.7323
# Epoch 44/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5169 - accuracy: 0.7331
# Epoch 45/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5163 - accuracy: 0.7364
# Epoch 46/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5154 - accuracy: 0.7339
# Epoch 47/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5149 - accuracy: 0.7339
# Epoch 48/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.5141 - accuracy: 0.7339
# Epoch 49/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5135 - accuracy: 0.7389
# Epoch 50/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5125 - accuracy: 0.7373

# %% [markdown]
# ### Step 3: Evaluate the model using the test data to determine the model’s loss and accuracy.

# %%
# Evaluate the model loss and accuracy metrics using the evaluate method and the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled, y_test, verbose=2)

# Display the model loss and accuracy results
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 13/13 - 0s - loss: 0.5190 - accuracy: 0.7300 - 184ms/epoch - 14ms/step
# Loss: 0.5190001130104065, Accuracy: 0.7300000190734863

# %% [markdown]
# ### Step 4: Save and export your model to a keras file, and name the file `student_loans.keras`.

# %%
# Set the model's file path
file_path = Path("student_loans.keras")

# Export your model to a keras file
nn_model.save(file_path)

# %% [markdown]
# ---
# ## Predict Loan Repayment Success by Using your Neural Network Model

# %% [markdown]
# ### Step 1: Reload your saved model.

# %%
# Set the model's file path
file_path = Path("student_loans.keras")

# Load the model to a new object
nn_imported = tf.keras.models.load_model(file_path)

# %% [markdown]
# ### Step 2: Make predictions on the testing data and save the predictions to a DataFrame.

# %%
# Make predictions with the test data
predictions = nn_model.predict(X_test_scaled, verbose=2)

# Display a sample of the predictions
predictions[:5]
# Out:
# 13/13 - 0s - 58ms/epoch - 4ms/step
# array([[0.52410024],
#        [0.24682096],
#        [0.8400549 ],
#        [0.62360704],
#        [0.96626806]], dtype=float32)

# %%
# Save the predictions to a DataFrame and round the predictions to binary results
predictions_df = pd.DataFrame(columns=["predictions"], data=predictions)
predictions_df["predictions"] = round(predictions_df["predictions"],0)
predictions_df
# Out:
#      predictions
# 0            1.0
# 1            0.0
# 2            1.0
# 3            1.0
# 4            1.0
# ..           ...
# 395          1.0
# 396          0.0
# 397          1.0
# 398          0.0
# 399          1.0
#
# [400 rows x 1 columns]

# %% [markdown]
# ### Step 4: Display a classification report with the y test data and predictions

# %%
# Print the classification report with the y test data and predictions
print(classification_report(y_test, predictions_df["predictions"].values))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.78      0.73       188
#            1       0.78      0.68      0.73       212
#
#     accuracy                           0.73       400
#    macro avg       0.73      0.73      0.73       400
# weighted avg       0.74      0.73      0.73       400

# %% [markdown]
# ---
# ## Discuss creating a recommendation system for student loans

# %% [markdown]
# Briefly answer the following questions in the space provided:
#
# 1. Describe the data that you would need to collect to build a recommendation system to recommend student loan options for students. Explain why this data would be relevant and appropriate.
#
# 2. Based on the data you chose to use in this recommendation system, would your model be using collaborative filtering, content-based filtering, or context-based filtering? Justify why the data you selected would be suitable for your choice of filtering method.
#
# 3. Describe two real-world challenges that you would take into consideration while building a recommendation system for student loans. Explain why these challenges would be of concern for a student loan recommendation system.

# %% [markdown]
# **1. Describe the data that you would need to collect to build a recommendation system to recommend student loan options for students. Explain why this data would be relevant and appropriate.**
#
#
# **2. Based on the data you chose to use in this recommendation system, would your model be using collaborative filtering, content-based filtering, or context-based filtering? Justify why the data you selected would be suitable for your choice of filtering method.**
#
#
# **3. Describe two real-world challenges that you would take into consideration while building a recommendation system for student loans. Explain why these challenges would be of concern for a student loan recommendation system.**
